# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("vipoooool/new-plant-diseases-dataset")

print("Path to dataset files:", path)
# Out:
# ...
# Path to dataset files: /root/.cache/kagglehub/datasets/vipoooool/new-plant-diseases-dataset/versions/2

# %%
import shutil

# Define source and destination paths
source_path = path  # The path where kagglehub saved the dataset
destination_path = '/content/drive/MyDrive/Plant_Disease'  # Replace 'dataset_name' with your folder name in Drive

# Copy the dataset to Google Drive
shutil.copytree(source_path, destination_path, dirs_exist_ok=True)

print(f"Dataset saved to {destination_path}")
